# %% [markdown]
# <a href="https://colab.research.google.com/github/rasyaalya/dwdm/blob/main/P5_CovidCases.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_csv('Case.csv')
df1
# Out:
#     case_id          province             city  group  \
# 0   1000001             Seoul          Guro-gu   True
# 1   1000002             Seoul    Dongdaemun-gu   True
# 2   1000003             Seoul     Eunpyeong-gu   True
# 3   1000004             Seoul     Seongdong-gu   True
# 4   1000005             Seoul        Jongno-gu   True
# ..      ...               ...              ...    ...
# 76  6100004  Gyeongsangnam-do      Changwon-si   True
# 77  6100005  Gyeongsangnam-do  Changnyeong-gun   True
# 78  6100006  Gyeongsangnam-do  from other city   True
# 79  6100007  Gyeongsangnam-do                -  False
# 80  7000001           Jeju-do                -  False
#
#                    infection_case  confirmed   latitude   longitude
# 0             Guro-gu Call Center         79  37.508163  126.884387
# 1                   Dongan Church         24  37.592888  127.056766
# 2   Eunpyeong St. Mary's Hospital         14   37.63369    126.9165
# ...

# %%
df1.groupby('province')['confirmed'].sum()
# Out:
# province
# Busan                  91
# Chungcheongbuk-do      31
# Chungcheongnam-do     115
# Daegu                6066
# Daejeon                22
# Gangwon-do             29
# Gwangju                16
# Gyeonggi-do           164
# Gyeongsangbuk-do     1145
# Gyeongsangnam-do       85
# Incheon                30
# Jeju-do                 4
# Jeollabuk-do            7
# Jeollanam-do            4
# Sejong                 40
# Seoul                 218
# Ulsan                  28
# Name: confirmed, dtype: int64

# %%
df1.groupby('city')['confirmed'].sum()
# Out:
# city
# -                  2280
# Bonghwa-gun          58
# Boram-dong            8
# Changnyeong-gun       7
# Changwon-si           7
# Cheonan-si          104
# Cheongdo-gun        119
# Chilgok-gun          25
# Dongdaemun-gu        24
# Dongnae-gu           34
# Eojin-dong           28
# Eunpyeong-gu         14
# Geochang-gun         18
# Goesan-gun           11
# Guro-gu              79
# Gyeongsan-si         55
# Haeundae-gu           6
# Jin-gu                4
# Jongno-gu            10
# Jung-gu               7
# Nam-gu             4359
# Seongdong-gu         13
# Seongnam-si          41
# Seosan-si             8
# Suwon-si             10
# Suyeong-gu            6
# from other city     760
# Name: confirmed, dtype: int64
