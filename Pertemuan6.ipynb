# %% [markdown]
# <a href="https://colab.research.google.com/github/rasyaalya/dwdm/blob/main/Pertemuan6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('mushroom_dataset_new.csv')
df.head()
# Out:
#   cap-shape cap-surface cap-color  bruises    odor gill-attachment  \
# 0    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 1    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 2    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 3    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 4    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
#
#   gill-spacing gill-size gill-color stalk-shape  ... stalk-surface-below-ring  \
# 0      CROWDED    NARROW      WHITE    TAPERING  ...                   SMOOTH
# 1      CROWDED    NARROW      WHITE    TAPERING  ...                   SMOOTH
# 2      CROWDED    NARROW       PINK    TAPERING  ...                   SMOOTH
# 3      CROWDED    NARROW       PINK    TAPERING  ...                   SMOOTH
# 4      CROWDED    NARROW      BROWN    TAPERING  ...                   SMOOTH
#
#   stalk-color-above-ring stalk-color-below-ring veil-color ring-number  \
# ...

# %%
df['mushroom'].value_counts()
# Out:
# EDIBLE       4488
# POISONOUS    3928
# Name: mushroom, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

df = df.apply(LabelEncoder().fit_transform)
df
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             2            3          8        0     0                1
# 1             2            3          8        0     0                1
# 2             2            3          8        0     0                1
# 3             2            3          8        0     0                1
# 4             2            3          8        0     0                1
# ...         ...          ...        ...      ...   ...              ...
# 8411          4            3          0        1     6                0
# 8412          4            3          0        1     6                0
# 8413          4            3          0        1     6                0
# 8414          4            3          0        1     6                0
# 8415          4            3          0        1     6                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
from sklearn.model_selection import train_test_split

features = df.iloc[:,:21]
label = df.iloc[:,21]

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30,random_state=42)

from sklearn.neighbors import GaussianNB
model = GaussianNB()
model = model.fit(x_train,y_train)
print(model.predict(x_test))
print(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5fcf74ce2643> in <module>
#       4 label = df.iloc[:,21]
#       5
# ----> 6 x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30,random_state=42)
#       7
#       8 from sklearn.neighbors import GaussianNB
#
# NameError: name 'x' is not defined

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model = model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-beaafb407caa> in <module>
#       1 from sklearn.naive_bayes import GaussianNB
#       2 model = GaussianNB()
# ----> 3 model = model.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
from sklearn.metrics import accuracy_score
hasil_prediksi = model.predict(x_test)
accuracy_scorely_test, hasil_prediksi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a1c45bf22f98> in <module>
#       1 from sklearn.metrics import accuracy_score
# ----> 2 hasil_prediksi = model.predict(x_test)
#       3 accuracy_scorely_test, (hasil_prediksi)
#
# NameError: name 'x_test' is not defined
